# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sb

# %%
train = pd.read_csv('train.csv')
test= pd.read_csv('test.csv')

# %%
train.SalePrice = np.log(train.SalePrice)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.PoolQC.fillna('None',inplace=True)
test.PoolQC.fillna('None',inplace=True)

# %%
train.MiscFeature.fillna('None',inplace=True)
test.MiscFeature.fillna('None',inplace=True)
train.MasVnrArea.fillna(train.MasVnrArea.mean(),inplace=True)
test.MasVnrArea.fillna(train.MasVnrArea.mean(),inplace=True)

# %%
train.Fence.fillna("None",inplace=True)
train.Alley.fillna("None",inplace=True)
train.FireplaceQu.fillna("None",inplace=True)
train.LotFrontage.fillna(train.LotFrontage.mean(),inplace=True)
train['GarageYrBlt'].fillna(0,inplace=True)
train.fillna('None',inplace=True)
test.Fence.fillna("None",inplace=True)
test.Alley.fillna("None",inplace=True)
test.FireplaceQu.fillna("None",inplace=True)
test.LotFrontage.fillna(train.LotFrontage.mean(),inplace=True)
test.GarageYrBlt.fillna(0,inplace=True)
test.GarageCond.fillna('None',inplace=True)
test.GarageQual.fillna('None',inplace=True)
test.GarageFinish.fillna('None',inplace=True)
test.GarageType.fillna('None',inplace=True)
test.BsmtCond.fillna(0,inplace=True)
test.GarageCond.fillna('None',inplace=True)
test.GarageQual.fillna('None',inplace=True)
test.GarageFinish.fillna('None',inplace=True)
test.GarageType.fillna('None',inplace=True)
#test.fillna(test.mode().iloc[0],inplace=True)

# %%
train.BsmtFinType1.unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', 'None', 'LwQ'], dtype=object)

# %%
test.isnull().sum().sort_values()[::-1]
# Out:
# BsmtCond         45
# BsmtQual         44
# BsmtExposure     44
# BsmtFinType2     42
# BsmtFinType1     42
# MasVnrType       16
# MSZoning          4
# BsmtHalfBath      2
# BsmtFullBath      2
# Functional        2
# Utilities         2
# Exterior2nd       1
# SaleType          1
# KitchenQual       1
# TotalBsmtSF       1
# Exterior1st       1
# BsmtUnfSF         1
# GarageArea        1
# GarageCars        1
# BsmtFinSF2        1
# BsmtFinSF1        1
# ExterCond         0
# MasVnrArea        0
# ExterQual         0
# Foundation        0
# RoofMatl          0
# SaleCondition     0
# RoofStyle         0
# LotConfig         0
# MSSubClass        0
#                  ..
# MoSold            0
# MiscVal           0
# MiscFeature       0
# Fence             0
# PoolQC            0
# PoolArea          0
# ScreenPorch       0
# 3SsnPorch         0
# EnclosedPorch     0
# OpenPorchSF       0
# WoodDeckSF        0
# PavedDrive        0
# GarageCond        0
# GarageFinish      0
# ...

# %%
sb.distplot(train['SalePrice'])
# Out:
# C:\Users\ADMIN\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sb.scatterplot(scipy.stats.boxcox(train.LotArea)[0],y=train.SalePrice)

# %%
sb.scatterplot(train['OverallQual'],y=train.SalePrice)

# %%
scipy.stats.boxcox(train.LotArea)
# Out:
# (array([10.43368   , 10.60280927, 10.81397325, ..., 10.52335162,
#         10.61890088, 10.64865655]), 0.030946318971935564)

# %%
np.corrcoef(scipy.stats.boxcox(train.LotArea)[0],np.log(train.SalePrice))
# Out:
# array([[1.        , 0.40027265],
#        [0.40027265, 1.        ]])

# %%
sb.countplot(train.BsmtQual)

# %%
plt.figure(figsize=(30,30))
sb.heatmap(train[col_real].corr(),annot=True)
plt.xticks(rotation=90)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5,
#         33.5, 34.5, 35.5, 36.5]), <a list of 37 Text xticklabel objects>)

# %%
train.columns[train.dtypes==object]
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
#        'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
col_real = train.columns[train.dtypes!=object]

# %%
train[col_real].hist(figsize=(14,14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E76BEF4978>,
# ...
#       dtype=object)

# %%
cols_skew = col_real[train[col_real].apply(lambda x:x.skew()).sort_values()>1]
train[cols_skew].apply(lambda x:np.log(x+1)).hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E76E51C080>,
# ...
#       dtype=object)

# %%
train[cols_skew]=train[cols_skew].apply(lambda x:scipy.stats.boxcox(x+1)[0])
test[cols_skew[:-1]]=test[cols_skew[:-1]].apply(lambda x:scipy.stats.boxcox(x+1)[0])

# %%
cols_skew
# Out:
# Index(['FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
train['MasVnrArea'].unique()
# Out:
# array([1.96000000e+02, 0.00000000e+00, 1.62000000e+02, 3.50000000e+02,
#        1.86000000e+02, 2.40000000e+02, 2.86000000e+02, 3.06000000e+02,
#        2.12000000e+02, 1.80000000e+02, 3.80000000e+02, 2.81000000e+02,
#        6.40000000e+02, 2.00000000e+02, 2.46000000e+02, 1.32000000e+02,
#        6.50000000e+02, 1.01000000e+02, 4.12000000e+02, 2.72000000e+02,
#        4.56000000e+02, 1.03100000e+03, 1.78000000e+02, 5.73000000e+02,
#        3.44000000e+02, 2.87000000e+02, 1.67000000e+02, 1.11500000e+03,
#        4.00000000e+01, 1.04000000e+02, 5.76000000e+02, 4.43000000e+02,
#        4.68000000e+02, 6.60000000e+01, 2.20000000e+01, 2.84000000e+02,
#        7.60000000e+01, 2.03000000e+02, 6.80000000e+01, 1.83000000e+02,
#        4.80000000e+01, 2.80000000e+01, 3.36000000e+02, 6.00000000e+02,
#        7.68000000e+02, 4.80000000e+02, 2.20000000e+02, 1.84000000e+02,
#        1.12900000e+03, 1.16000000e+02, 1.35000000e+02, 2.66000000e+02,
# ...

# %%
from sklearn import preprocessing
obj = train.columns[train.dtypes==object]
for c in obj:
    lbl = preprocessing.LabelEncoder() 
    lbl.fit(list(train[c].values)) 
    print(c)
    test[c] = lbl.transform(list(test[c].values))
    train[c] = lbl.transform(list(train[c].values))
# Out:
# MSZoning
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# PoolQC
# Fence
# MiscFeature
# SaleType
# SaleCondition

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error,make_scorer

# %%
parameters = {'alpha':np.linspace(0,10)}

# %%
ridge = Ridge()
clf = GridSearchCV(ridge, parameters, cv=3,scoring=make_scorer(mean_squared_error))
clf.fit(train[train.columns[1:-1]],train[train.columns[-1]])
# Out:
# C:\Users\ADMIN\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.239562e-19
#   overwrite_a=True).T
# GridSearchCV(cv=3, error_score='raise',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'alpha': array([ 0.     ,  0.20408,  0.40816,  0.61224,  0.81633,  1.02041,
#         1.22449,  1.42857,  1.63265,  1.83673,  2.04082,  2.2449 ,
#         2.44898,  2.65306,  2.85714,  3.06122,  3.26531,  3.46939,
#         3.67347,  3.87755,  4.08163,  4.28571,  4.4898 ,  4.69388,
#         4.8...735,
#         8.57143,  8.77551,  8.97959,  9.18367,  9.38776,  9.59184,
#         9.79592, 10.     ])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
# ...

# %%
mean_squared_error(clf.predict(train[train.columns[1:-1]]),train[train.columns[-1]])
# Out:
# 0.01794546204934107

# %%
plt.hist(np.exp(train[train.columns[-1]]))
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <a list of 10 Patch objects>)

# %%
np.exp(clf.predict(test[train.columns[1:-1]]))
# Out:
# array([114687.12208111, 159006.16159129, 165701.27214289, ...,
#        152196.78996058, 118767.53057961, 242145.93388701])

# %%
plt.hist(np.exp(clf.predict(train[train.columns[1:-1]])))
# Out:
# (array([  5.,  33., 179., 388., 373., 298., 127.,  42.,  11.,   4.]),
#  array([15.06631701, 15.49248912, 15.91866123, 16.34483333, 16.77100544,
#         17.19717755, 17.62334966, 18.04952176, 18.47569387, 18.90186598,
#         19.32803809]),
#  <a list of 10 Patch objects>)

# %%
ensemble = scipy.special.inv_boxcox(clf.predict(test[train.columns[1:-1]]),-0.07692396374428875)
plt.hist(ensemble)
# Out:
# (array([ 10.,  42., 193., 473., 398., 226.,  94.,  21.,   1.,   1.]),
#  array([7.35170528e-83, 7.35170537e-83, 7.35170547e-83, 7.35170557e-83,
#         7.35170566e-83, 7.35170576e-83, 7.35170585e-83, 7.35170595e-83,
#         7.35170604e-83, 7.35170614e-83, 7.35170623e-83]),
#  <a list of 10 Patch objects>)

# %%
test.index
# Out:
# RangeIndex(start=0, stop=1459, step=1)

# %%
sub = pd.DataFrame()
sub['Id'] = test.Id
sub['SalePrice'] = np.exp(clf.predict(test[train.columns[1:-1]]))
sub.to_csv('submission.csv',index=False)
